# %% [markdown]
# ### 위성사진 api 호출

# %%
import urllib
from urllib.request import urlopen
from urllib.parse import urlencode, quote_plus

url = 'http://apis.data.go.kr/1360000/SatlitImgInfoService/getInsightSatlit'
queryParams = '?' + urlencode({ quote_plus('ServiceKey') : 'zkwKOhULzACqZDpQze92X07T7ZKmqj+UPdYt29/2NT7ujTCl4MaGwBOk2SOVQTaRdOUWpogDkwOrQnwGqx31cg==', quote_plus('pageNo') : '1', quote_plus('numOfRows') : '10', quote_plus('dataType') : 'XML', quote_plus('sat') : 'G2', quote_plus('data') : 'wv069', quote_plus('area') : 'ko', quote_plus('time') : '20211027' })


print ('Your Request:\n'+url+queryParams)
request = urllib.request.Request(url + queryParams)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
print(response_body)
# Out:
# Your Request:
# http://apis.data.go.kr/1360000/SatlitImgInfoService/getInsightSatlit?ServiceKey=zkwKOhULzACqZDpQze92X07T7ZKmqj%2BUPdYt29%2F2NT7ujTCl4MaGwBOk2SOVQTaRdOUWpogDkwOrQnwGqx31cg%3D%3D&pageNo=1&numOfRows=10&dataType=XML&sat=G2&data=wv069&area=ko&time=20211027
# ...
